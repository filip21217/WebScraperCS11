# %% [markdown]
# # Packages import

# %%
import yaml
import requests
import pandas as pd
from requests.auth import HTTPBasicAuth
from bs4 import BeautifulSoup

# %% [markdown]
# # Apollo scraper

# %%
with open ("config.yaml", 'r', encoding= "UTF-8") as yf:
    config = yaml.safe_load(yf)
username = config['credentials']['user']
password = config['credentials']['password']
credentials = HTTPBasicAuth('user', 'pass')

# %%
url = 'https://planzajec.uek.krakow.pl/index.php?typ=G&id=252681&okres=2'
response = requests.get(url, auth=credentials)
print(response.status_code)
# Out:
# 401

# %%
page_dom =BeautifulSoup(response.text, 'html.parser', from_encoding='UTF-8')
# Out:
# d:\filipg\WebScraperCS11\.venv\Lib\site-packages\bs4\__init__.py:341: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn(

# %%
group = page_dom.select_one("div.grupa").get_text(strip=True)
print(group)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 group = page_dom.select_one("div.grupa").get_text(strip=True)
#       2 print(group)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
classes_tag = page_dom.select.one("table")
with open("temp.html", "w", encoding="UTF-8") as hf:
    hf.write(classes_tag.prettify())
